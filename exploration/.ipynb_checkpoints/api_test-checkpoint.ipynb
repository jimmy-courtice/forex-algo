# %%
import requests
import pandas as pd
import json
from dateutil import parser

# %%
API_KEY = "4d98d7da7ccfa2a8762347a73ff0adf3-3096846bf9b92a8cc3b3d88654d16a28"
ACCOUNT_ID = "101-001-27395881-001"
OANDA_URL = "https://api-fxpractice.oanda.com"

# %%
session = requests.Session()

# %%
session.headers.update({
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
})

# %%
params = dict(
count = 10,
granularity = "H1",
price = 'MBA'
)

# %%
url = f"{OANDA_URL}/v3/accounts/{ACCOUNT_ID}/instruments"

# %%
response = session.get(url, params=params, data=None, headers=None)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['instruments', 'lastTransactionID'])

# %%
instruments_list = data['instruments']
len(instruments_list)
# Out:
# 68

# %%
instruments_list[0].keys()
# Out:
# dict_keys(['name', 'type', 'displayName', 'pipLocation', 'displayPrecision', 'tradeUnitsPrecision', 'minimumTradeSize', 'maximumTrailingStopDistance', 'minimumTrailingStopDistance', 'maximumPositionSize', 'maximumOrderUnits', 'marginRate', 'guaranteedStopLossOrderMode', 'tags', 'financing'])

# %%
keys_i = ['name', 'type', 'displayName', 'pipLocation', 'displayPrecision', 'tradeUnitsPrecision', 'marginRate']

# %%
instruments_dict = {}
for i in instruments_list:
    key = i['name']
    instruments_dict[key] = {k: i[k] for k in keys_i}

# %%
instruments_dict
# Out:
# {'USD_SGD': {'name': 'USD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'USD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_SEK': {'name': 'EUR_SEK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/SEK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'HKD_JPY': {'name': 'HKD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'HKD/JPY',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'AUD_USD': {'name': 'AUD_USD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'USD_CAD': {'name': 'USD_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.02'},
#  'NZD_USD': {'name': 'NZD_USD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'NZD_SGD': {'name': 'NZD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_NOK': {'name': 'USD_NOK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/NOK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.07'},
#  'USD_CNH': {'name': 'USD_CNH',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CNH',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'SGD_CHF': {'name': 'SGD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'SGD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_JPY': {'name': 'GBP_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_TRY': {'name': 'USD_TRY',
#   'type': 'CURRENCY',
#   'displayName': 'USD/TRY',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.25'},
#  'AUD_JPY': {'name': 'AUD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'ZAR_JPY': {'name': 'ZAR_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'ZAR/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.07'},
#  'SGD_JPY': {'name': 'SGD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'SGD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_ZAR': {'name': 'GBP_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.07'},
#  'USD_JPY': {'name': 'USD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'USD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_TRY': {'name': 'EUR_TRY',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/TRY',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.25'},
#  'EUR_JPY': {'name': 'EUR_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'AUD_SGD': {'name': 'AUD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_NZD': {'name': 'EUR_NZD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/NZD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'GBP_HKD': {'name': 'GBP_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'CHF_JPY': {'name': 'CHF_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'CHF/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_HKD': {'name': 'EUR_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'GBP_CAD': {'name': 'GBP_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_THB': {'name': 'USD_THB',
#   'type': 'CURRENCY',
#   'displayName': 'USD/THB',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_CHF': {'name': 'GBP_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'AUD_CHF': {'name': 'AUD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'NZD_CHF': {'name': 'NZD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'AUD_HKD': {'name': 'AUD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'USD_CHF': {'name': 'USD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'CAD_HKD': {'name': 'CAD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'EUR_CHF': {'name': 'EUR_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'EUR_SGD': {'name': 'EUR_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'NZD_CAD': {'name': 'NZD_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'GBP_AUD': {'name': 'GBP_AUD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/AUD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_PLN': {'name': 'USD_PLN',
#   'type': 'CURRENCY',
#   'displayName': 'USD/PLN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_ZAR': {'name': 'EUR_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.07'},
#  'TRY_JPY': {'name': 'TRY_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'TRY/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.25'},
#  'EUR_AUD': {'name': 'EUR_AUD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/AUD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'USD_ZAR': {'name': 'USD_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'USD/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.07'},
#  'CAD_JPY': {'name': 'CAD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'NZD_HKD': {'name': 'NZD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'USD_CZK': {'name': 'USD_CZK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/CZK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_DKK': {'name': 'USD_DKK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/DKK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.02'},
#  'USD_SEK': {'name': 'USD_SEK',
#   'type': 'CURRENCY',
#   'displayName': 'USD/SEK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'GBP_SGD': {'name': 'GBP_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_DKK': {'name': 'EUR_DKK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/DKK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'CHF_ZAR': {'name': 'CHF_ZAR',
#   'type': 'CURRENCY',
#   'displayName': 'CHF/ZAR',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.07'},
#  'CAD_CHF': {'name': 'CAD_CHF',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/CHF',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.04'},
#  'GBP_USD': {'name': 'GBP_USD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_MXN': {'name': 'USD_MXN',
#   'type': 'CURRENCY',
#   'displayName': 'USD/MXN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.10'},
#  'USD_HUF': {'name': 'USD_HUF',
#   'type': 'CURRENCY',
#   'displayName': 'USD/HUF',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'USD_HKD': {'name': 'USD_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'USD/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'EUR_USD': {'name': 'EUR_USD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/USD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.02'},
#  'EUR_CAD': {'name': 'EUR_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.02'},
#  'AUD_CAD': {'name': 'AUD_CAD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/CAD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'GBP_PLN': {'name': 'GBP_PLN',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/PLN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_PLN': {'name': 'EUR_PLN',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/PLN',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'GBP_NZD': {'name': 'GBP_NZD',
#   'type': 'CURRENCY',
#   'displayName': 'GBP/NZD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_HUF': {'name': 'EUR_HUF',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/HUF',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_NOK': {'name': 'EUR_NOK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/NOK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.07'},
#  'CHF_HKD': {'name': 'CHF_HKD',
#   'type': 'CURRENCY',
#   'displayName': 'CHF/HKD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.1'},
#  'EUR_GBP': {'name': 'EUR_GBP',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/GBP',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'AUD_NZD': {'name': 'AUD_NZD',
#   'type': 'CURRENCY',
#   'displayName': 'AUD/NZD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.03'},
#  'CAD_SGD': {'name': 'CAD_SGD',
#   'type': 'CURRENCY',
#   'displayName': 'CAD/SGD',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'EUR_CZK': {'name': 'EUR_CZK',
#   'type': 'CURRENCY',
#   'displayName': 'EUR/CZK',
#   'pipLocation': -4,
#   'displayPrecision': 5,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'},
#  'NZD_JPY': {'name': 'NZD_JPY',
#   'type': 'CURRENCY',
#   'displayName': 'NZD/JPY',
#   'pipLocation': -2,
#   'displayPrecision': 3,
#   'tradeUnitsPrecision': 0,
#   'marginRate': '0.05'}}

# %%
with open("../data/instruments.json", "w") as f:
    f.write(json.dumps(instruments_dict,indent=2))

# %%
def fetch_candles(pair_name, count=10, granularity="H1"):
    url = f"{OANDA_URL}/v3/instruments/{pair_name}/candles"
    params = dict(
        count = count,
        granularity = granularity,
        price = 'MBA'
    )
    response = session.get(url, params=params, data=None, headers=None)
    data = response.json()

    if response.status_code == 200:
        if 'candles' not in data:
            data = []
        else:
            data = data['candles']
    return response.status_code, data

def get_candles_df(data):
    if len(data) == 0:
        return pd.DataFrame()
    prices = ['mid', 'bid', 'ask']
    ohlc = ['o', 'h', 'l', 'c']
    
    final_data = []
    for candle in data:
        if candle['complete'] == False:
            continue
        new_dict = {}
        new_dict['time'] = parser.parse(candle['time'])
        new_dict['volume'] = candle['volume']
        for p in prices:
            for o in ohlc:
                new_dict[f"{p}_{o}"] = float(candle[p][o])
        final_data.append(new_dict)
    df = pd.DataFrame.from_dict(final_data)
    return df

def create_data_file(pair_name, count=10, granularity="H1"):
    code, data = fetch_candles(pair_name, count, granularity)
    if code != 200:
        print("Failed", pair_name, data)
    if len(data) == 0:
        print("No candles", pair_name)
    candles_df = get_candles_df(data)
    candles_df.to_pickle(f"../data/{pair_name}_{granularity}.pkl")
    print(f"{pair_name} {granularity} {candles_df.shape[0]} candles, {candles_df.time.min()} {candles_df.time.max()}")

# %%
our_curr = ['EUR', 'USD', 'GBP', 'JPY', 'CHF', 'NZD', 'CAD', 'AUD']

# %%
for p1 in our_curr:
    for p2 in our_curr:
        pr = f"{p1}_{p2}"
        if pr in instruments_dict:
            for g in ["H1", "H4"]:
                create_data_file(pr, count=4001, granularity=g)
# Out:
# EUR_USD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# EUR_USD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# EUR_GBP H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# EUR_GBP H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# EUR_JPY H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# EUR_JPY H4 4001 candles, 2021-04-27 17:00:00+00:00 2023-11-17 18:00:00+00:00
# EUR_CHF H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# EUR_CHF H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# EUR_NZD H1 4001 candles, 2023-03-30 03:00:00+00:00 2023-11-17 21:00:00+00:00
# EUR_NZD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# EUR_CAD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# EUR_CAD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# EUR_AUD H1 4001 candles, 2023-03-30 03:00:00+00:00 2023-11-17 21:00:00+00:00
# EUR_AUD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# USD_JPY H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# USD_JPY H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# USD_CHF H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# USD_CHF H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# USD_CAD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# USD_CAD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# GBP_USD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# GBP_USD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# GBP_JPY H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# GBP_JPY H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# GBP_CHF H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# GBP_CHF H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# GBP_NZD H1 4001 candles, 2023-03-30 03:00:00+00:00 2023-11-17 21:00:00+00:00
# GBP_NZD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# GBP_CAD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# GBP_CAD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# GBP_AUD H1 4001 candles, 2023-03-30 01:00:00+00:00 2023-11-17 21:00:00+00:00
# GBP_AUD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# CHF_JPY H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# CHF_JPY H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# NZD_USD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# NZD_USD H4 4001 candles, 2021-04-28 09:00:00+00:00 2023-11-17 18:00:00+00:00
# NZD_JPY H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# NZD_JPY H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# NZD_CHF H1 4001 candles, 2023-03-29 21:00:00+00:00 2023-11-17 21:00:00+00:00
# NZD_CHF H4 4001 candles, 2021-04-27 21:00:00+00:00 2023-11-17 18:00:00+00:00
# NZD_CAD H1 4001 candles, 2023-03-30 03:00:00+00:00 2023-11-17 21:00:00+00:00
# NZD_CAD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# CAD_JPY H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# CAD_JPY H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# CAD_CHF H1 4001 candles, 2023-03-30 02:00:00+00:00 2023-11-17 21:00:00+00:00
# CAD_CHF H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# AUD_USD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# AUD_USD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
# AUD_JPY H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# AUD_JPY H4 4001 candles, 2021-04-29 01:00:00+00:00 2023-11-17 18:00:00+00:00
# AUD_CHF H1 4001 candles, 2023-03-30 03:00:00+00:00 2023-11-17 21:00:00+00:00
# AUD_CHF H4 4001 candles, 2021-04-27 21:00:00+00:00 2023-11-17 18:00:00+00:00
# AUD_NZD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# AUD_NZD H4 4001 candles, 2021-04-27 21:00:00+00:00 2023-11-17 18:00:00+00:00
# AUD_CAD H1 4001 candles, 2023-03-30 04:00:00+00:00 2023-11-17 21:00:00+00:00
# AUD_CAD H4 4001 candles, 2021-04-28 01:00:00+00:00 2023-11-17 18:00:00+00:00
